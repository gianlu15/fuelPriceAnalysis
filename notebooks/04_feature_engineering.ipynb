# %% [markdown]
# # Feature Engineering (Building the Training Dataset)

# %% [markdown]
# The goal is create new columns (features) that help the model understand:
# - recent trends
# - momentum
# - delayed effects
# - volatility
# - seasonality
# - relationships between benzina, gasolio, and Brent
#
# These features will make your model smarter than the naïve baseline.

# %%
import pandas as pd

weekly = pd.read_csv('../data/processed/weekly_dataset.csv', parse_dates=['date'])
weekly = weekly.sort_values('date').reset_index(drop=True)
weekly.set_index('date', inplace=True)

# %% [markdown]
# ## Creating LAG features
# Fuel prices depend strongly on previous weeks’ values and Brent effects also appear with delay (1–3 weeks). 12 new colunms will be added.

# %%
lags = [1, 2, 3, 4]

for col in ['benzina', 'gasolio', 'brent_eur']:
    for lag in lags:
        weekly[f'{col}_lag{lag}'] = weekly[col].shift(lag)

# %% [markdown]
# ## Rolling averages (smooth trends)
# Fuel prices follow smoothed trends. Models learn better with rolling statistics.

# %%
windows = [4, 8]

for col in ['benzina', 'gasolio', 'brent_eur']:
    for W in windows:
        weekly[f'{col}_roll{W}'] = weekly[col].rolling(W).mean()

# %% [markdown]
# ## Percentage changes
# Models need to understand acceleration/inversion of trends.

# %%
weekly['brent_pct_change'] = weekly['brent_eur'].pct_change()
weekly['benzina_pct_change'] = weekly['benzina'].pct_change()
weekly['gasolio_pct_change'] = weekly['gasolio'].pct_change()

# %% [markdown]
# ## Price spreads
# Difference between fuels reflects refinery margins and can predict future movement.

# %%
weekly['spread_bg'] = weekly['benzina'] - weekly['gasolio']
weekly['spread_bg_lag1'] = weekly['spread_bg'].shift(1)

# %% [markdown]
# ## Calendar features

# %%
weekly['month'] = weekly.index.month
weekly['weekofyear'] = weekly.index.isocalendar().week.astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1048 entries, 2005-01-03 to 2025-11-03
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   benzina             1048 non-null   float64
#  1   gasolio             1048 non-null   float64
#  2   brent_eur           1048 non-null   float64
#  3   benzina_lag1        1047 non-null   float64
#  4   benzina_lag2        1046 non-null   float64
#  5   benzina_lag3        1045 non-null   float64
#  6   benzina_lag4        1044 non-null   float64
#  7   gasolio_lag1        1047 non-null   float64
#  8   gasolio_lag2        1046 non-null   float64
#  9   gasolio_lag3        1045 non-null   float64
#  10  gasolio_lag4        1044 non-null   float64
#  11  brent_eur_lag1      1047 non-null   float64
#  12  brent_eur_lag2      1046 non-null   float64
#  13  brent_eur_lag3      1045 non-null   float64
#  14  brent_eur_lag4      1044 non-null   float64
#  15  benzina_roll4       1045 non-null   float64
#  16  benzina_roll8       1041 non-null   float64
#  17  gasolio_roll4       1045 non-null   float64
#  18  gasolio_roll8       1041 non-null   float64
#  19  brent_eur_roll4     1045 non-null   float64
#  20  brent_eur_roll8     1041 non-null   float64
#  21  brent_pct_change    1047 non-null   float64
#  22  benzina_pct_change  1047 non-null   float64
#  23  gasolio_pct_change  1047 non-null   float64
#  24  spread_bg           1048 non-null   float64
#  25  spread_bg_lag1      1047 non-null   float64
#  26  month               1048 non-null   int32
#  27  weekofyear          1048 non-null   int64
# dtypes: float64(26), int32(1), int64(1)
# memory usage: 233.3 KB
#             benzina  gasolio  brent_eur  benzina_lag1  benzina_lag2  \
# date
# 2005-01-03  1.11575  1.01828  33.075880           NaN           NaN
# 2005-01-10  1.08800  1.00439  34.449450       1.11575           NaN
# 2005-01-17  1.08814  1.00431  35.047472       1.08800       1.11575
# 2005-01-24  1.09001  1.00431  34.463165       1.08814       1.08800
# 2005-01-31  1.13211  1.02260  34.093752       1.09001       1.08814
#
#             benzina_lag3  benzina_lag4  gasolio_lag1  gasolio_lag2  \
# date
# 2005-01-03           NaN           NaN           NaN           NaN
# 2005-01-10           NaN           NaN       1.01828           NaN
# 2005-01-17           NaN           NaN       1.00439       1.01828
# 2005-01-24       1.11575           NaN       1.00431       1.00439
# 2005-01-31       1.08800       1.11575       1.00431       1.00431
#
#             gasolio_lag3  ...  gasolio_roll8  brent_eur_roll4  \
# date                      ...
# 2005-01-03           NaN  ...            NaN              NaN
# 2005-01-10           NaN  ...            NaN              NaN
# 2005-01-17           NaN  ...            NaN              NaN
# 2005-01-24       1.01828  ...            NaN        34.258992
# 2005-01-31       1.00439  ...            NaN        34.513460
#
#             brent_eur_roll8  brent_pct_change  benzina_pct_change  \
# date
# 2005-01-03              NaN               NaN                 NaN
# 2005-01-10              NaN          0.041528           -0.024871
# 2005-01-17              NaN          0.017359            0.000129
# 2005-01-24              NaN         -0.016672            0.001719
# 2005-01-31              NaN         -0.010719            0.038623
#
#             gasolio_pct_change  spread_bg  spread_bg_lag1  month  weekofyear
# date
# 2005-01-03                 NaN    0.09747             NaN      1           1
# 2005-01-10           -0.013641    0.08361         0.09747      1           2
# 2005-01-17           -0.000080    0.08383         0.08361      1           3
# 2005-01-24            0.000000    0.08570         0.08383      1           4
# 2005-01-31            0.018212    0.10951         0.08570      1           5
#
# [5 rows x 28 columns]

# %%
features = weekly.dropna().reset_index()
features.info()
features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                1041 non-null   datetime64[ns]
#  1   benzina             1041 non-null   float64
#  2   gasolio             1041 non-null   float64
#  3   brent_eur           1041 non-null   float64
#  4   benzina_lag1        1041 non-null   float64
#  5   benzina_lag2        1041 non-null   float64
#  6   benzina_lag3        1041 non-null   float64
#  7   benzina_lag4        1041 non-null   float64
#  8   gasolio_lag1        1041 non-null   float64
#  9   gasolio_lag2        1041 non-null   float64
#  10  gasolio_lag3        1041 non-null   float64
#  11  gasolio_lag4        1041 non-null   float64
#  12  brent_eur_lag1      1041 non-null   float64
#  13  brent_eur_lag2      1041 non-null   float64
#  14  brent_eur_lag3      1041 non-null   float64
#  15  brent_eur_lag4      1041 non-null   float64
#  16  benzina_roll4       1041 non-null   float64
#  17  benzina_roll8       1041 non-null   float64
#  18  gasolio_roll4       1041 non-null   float64
#  19  gasolio_roll8       1041 non-null   float64
#  20  brent_eur_roll4     1041 non-null   float64
#  21  brent_eur_roll8     1041 non-null   float64
#  22  brent_pct_change    1041 non-null   float64
#  23  benzina_pct_change  1041 non-null   float64
#  24  gasolio_pct_change  1041 non-null   float64
#  25  spread_bg           1041 non-null   float64
#  26  spread_bg_lag1      1041 non-null   float64
#  27  month               1041 non-null   int32
#  28  weekofyear          1041 non-null   int64
# dtypes: datetime64[ns](1), float64(26), int32(1), int64(1)
# memory usage: 231.9 KB
#         date  benzina  gasolio  brent_eur  benzina_lag1  benzina_lag2  \
# 0 2005-02-21  1.13604  1.02279  37.460511       1.13588       1.13587
# 1 2005-02-28  1.13604  1.02285  39.119360       1.13604       1.13588
# 2 2005-03-07  1.15878  1.04759  39.469230       1.13604       1.13604
# 3 2005-03-14  1.18590  1.07272  41.748090       1.15878       1.13604
# 4 2005-03-21  1.18598  1.07286  41.612388       1.18590       1.15878
#
#    benzina_lag3  benzina_lag4  gasolio_lag1  gasolio_lag2  ...  gasolio_roll8  \
# 0       1.13211       1.09001       1.02246       1.02267  ...       1.015226
# 1       1.13587       1.13211       1.02279       1.02246  ...       1.015798
# 2       1.13588       1.13587       1.02285       1.02279  ...       1.021197
# 3       1.13604       1.13588       1.04759       1.02285  ...       1.029749
# 4       1.13604       1.13604       1.07272       1.04759  ...       1.038318
#
#    brent_eur_roll4  brent_eur_roll8  brent_pct_change  benzina_pct_change  \
# 0        35.459129        34.859060          0.056573            0.000141
# 1        36.715531        35.614496          0.044283            0.000000
# 2        37.875959        36.241968          0.008944            0.020017
# 3        39.449298        37.079545          0.057738            0.023404
# 4        40.487267        37.973198         -0.003250            0.000067
#
#    gasolio_pct_change  spread_bg  spread_bg_lag1  month  weekofyear
# 0            0.000323    0.11325         0.11342      2           8
# 1            0.000059    0.11319         0.11325      2           9
# 2            0.024187    0.11119         0.11319      3          10
# 3            0.023988    0.11318         0.11119      3          11
# 4            0.000131    0.11312         0.11318      3          12
#
# [5 rows x 29 columns]

# %% [markdown]
# Save the feature dataset

# %%
features.to_csv('../data/processed/features_dataset.csv', index=False)
